# %%
import numpy as np

# %%
l1 = [x for x in range(1,1000000)]
l2 = [y for y in range(1,1000000)]

arr1 = np.array(l1)
arr2 = np.array(l2)

print(arr1 + arr2)
# Out:
# [      2       4       6 ... 1999994 1999996 1999998]
