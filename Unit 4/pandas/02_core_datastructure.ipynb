# %% [markdown]
# # Core Data Structure
#
#     1) Series - One Dimensional
#     2) Data frame - Two Dimensional

# %%
import pandas as pd

# %%
s1 = pd.Series([71,44,56,33,56,98,56])

# %%
print(type(s1))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(s1)
# Out:
# 0    71
# 1    44
# 2    56
# 3    33
# 4    56
# 5    98
# 6    56
# dtype: int64

# %%
s2 = pd.Series([71,44,56], index =["Harry","Shubh","Rohan"])

# %%
print(s2)
# Out:
# Harry    71
# Shubh    44
# Rohan    56
# dtype: int64

# %%
data = {
"name": ["Alice", "Bob", "Charlie"],
"age": [25, 30, 35],
"city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
pd.DataFrame(data)
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
